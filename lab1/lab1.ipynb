# %% [markdown]
# # Lab One

# %% [markdown]
# ## Activity One

# %%
import pandas as pd
import numpy as np

cars = pd.read_csv('cars.csv')

# %%
# print(cars.head())  # first 5 rows
# print(cars['cyl'])  # column 2
# print(cars.loc[7])  # row 8
# print(cars.iloc[7, 1])  # row 8, column 2
# print(cars.iloc[:, 1])  # all rows, column 2

cars.describe()  # summary statistics
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# ## Activity Two

# %%
import altair as alt

# %%
scatter_plot = alt.Chart(cars).mark_circle().encode(
    x = 'displ',
    y = 'hwy'
)

scatter_plot.show()
# Out:
# alt.Chart(...)

# %%
scatter_plot_colored = scatter_plot.encode(
    color = 'class'
)

scatter_plot_colored.show()
# Out:
# alt.Chart(...)

# %%
# cars_audi = cars[cars['manufacturer'] == 'audi']

scatter_plot = alt.Chart(cars).mark_circle().encode(
    x = 'displ',
    y = 'hwy',
    color = 'hwy',
    size = 'hwy'
)

scatter_plot.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Activity Three

# %%
alt.renderers.enable('default')
cars['mpg'] = (cars['cty'] + cars['hwy']) / 2

mean_mpg_by_manufacturer = cars.groupby('manufacturer')['mpg'].mean().reset_index()

bar_chart = alt.Chart(mean_mpg_by_manufacturer).mark_bar().encode(
    x = alt.X('manufacturer:N', sort='-y', title='manufacturer'),
    y = alt.Y('mean_mpg:Q', title='Mean MPG')
).properties(
    width=600,
    height=400,
    title='Mean MPG by Manufacturer'
)

bar_chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Activity Four
